# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## X label-encoded

# %%
X = train.drop(['PassengerId', 'Name', 'Cabin', 'Ticket', 'Survived'], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lbl1 = LabelEncoder()
X['Sex'] = lbl1.fit_transform(X['Sex'])
lbl2 = LabelEncoder()
X['Embarked'] = X['Embarked'].fillna('N')
X['Embarked'] = lbl2.fit_transform(X['Embarked'])
y = train['Survived']

# %%
X_nan = X.copy()
X_nan['Age'] = X_nan['Age'].fillna(X_nan['Age'].median()).astype(float)

# %% [markdown]
# ## Model selection

# %%
from sklearn.model_selection import cross_val_score
import time

from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.svm import SVC
from sklearn.svm import LinearSVC

from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import BernoulliNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import StratifiedKFold

# %%
kfolds = StratifiedKFold(shuffle=True, random_state=1)

# %%
def run_model(model, X, y):
    model_name = str(model.__class__).split('.')[-1].replace('>','').replace("'",'')
    print(model_name)
    accuracy = []
    f1 = []
    start = int(time.time() * 1000)
    for train_idx, test_idx in kfolds.split(X, y):
        model.fit(X.iloc[train_idx,:], y[train_idx])
        y_ = model.predict(X.iloc[test_idx,:])
        accuracy += [accuracy_score(y.iloc[test_idx], y_)]
        f1 += [f1_score(y.iloc[test_idx], y_)]
    end = int(time.time() * 1000)
    results.loc[len(results)] = [model_name, np.mean(accuracy), np.std(accuracy), 
                                 np.mean(f1), np.std(f1), str(end - start)]

# %%
def run_linear_models(X, y):
    run_model(LogisticRegression(), X, y)
    run_model(RidgeClassifier(), X, y)
    run_model(SGDClassifier(max_iter=1000), X, y)
    run_model(PassiveAggressiveClassifier(max_iter=1000), X, y)
    run_model(SVC(), X, y)
    run_model(LinearSVC(), X, y)
    run_model(MLPClassifier(max_iter=1000), X, y)
    
def run_misc_models(X, y):
#     run_model(GaussianNB(), X, y)
#     run_model(MultinomialNB(), X, y)
    run_model(BernoulliNB(), X, y)
    run_model(GaussianProcessClassifier(), X, y)
    run_model(KNeighborsClassifier(), X, y)
    run_model(DecisionTreeClassifier(), X, y)
    
def run_ensemble_models(X, y, X_nan):
    run_model(RandomForestClassifier(), X_nan, y)
    run_model(ExtraTreesClassifier(), X_nan, y)
    run_model(AdaBoostClassifier(), X_nan, y)
    run_model(GradientBoostingClassifier(), X_nan, y)    
    run_model(XGBClassifier(), X, y)
    run_model(LGBMClassifier(), X, y)
    run_model(CatBoostClassifier(), X, y)

# %%
results = pd.DataFrame(columns=['model', 'accuracy', 'accuracy-std', 'f1-score', 'f1-score-std', 'time'])

# %%
run_ensemble_models(X, y, X_nan)
# Out:
# RandomForestClassifier
# ExtraTreesClassifier
# AdaBoostClassifier
# GradientBoostingClassifier
# XGBClassifier
# LGBMClassifier
# CatBoostClassifier

# %%
run_misc_models(X_nan, y)
# Out:
# BernoulliNB
# GaussianProcessClassifier
# KNeighborsClassifier
# DecisionTreeClassifier

# %%
run_model(SGDClassifier(max_iter=100), X_nan, y)
# Out:
# SGDClassifier

# %%
results
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 2            AdaBoostClassifier  0.789001      0.008399  0.723547
# 3    GradientBoostingClassifier  0.824916      0.019244  0.757814
# 4                 XGBClassifier  0.821549      0.014547  0.756280
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 7            LogisticRegression  0.795735      0.019309  0.717724
# 8               RidgeClassifier  0.795735      0.011446  0.719034
# 9                 SGDClassifier  0.585859      0.016722  0.458404
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 11                          SVC  0.680135      0.020756  0.529953
# 12                    LinearSVC  0.613917      0.117583  0.526530
# 13                MLPClassifier  0.671156      0.034373  0.446757
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 19                SGDClassifier  0.622896      0.059537  0.469527
# 20                XGBClassifier  0.819304      0.013561  0.750959
# 21                XGBClassifier  0.824916      0.012598  0.757413
#
#     f1-score-std   time
# 0       0.024212    111
# 1       0.007580     64
# 2       0.021509    256
# 3       0.025988    202
# 4       0.022376    116
# 5       0.019489     49
# 6       0.015169  26554
# 7       0.022204     44
# 8       0.017241     74
# 9       0.126533     27
# 10      0.073323     24
# 11      0.066454    130
# 12      0.107063    129
# 13      0.069996    137
# 14      0.051903     35
# 15      0.037302     37
# 16      0.040408    851
# 17      0.030389     31
# 18      0.016951     24
# 19      0.087364     40
# 20      0.020572    153
# 21      0.021329    134

# %% [markdown]
# ## Normalize

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    1  22.0      1      0   7.2500         3
# 1       1    0  38.0      1      0  71.2833         0
# 2       3    0  26.0      0      0   7.9250         3
# 3       1    0  35.0      1      0  53.1000         3
# 4       3    1  35.0      0      0   8.0500         3

# %%
X_norm = X_nan.copy()

# %%
sc1 = MinMaxScaler()
X_norm['Age'] = sc1.fit_transform(X_norm['Age'].values.reshape((-1, 1)))
sc2 = MinMaxScaler()
X_norm['Fare'] = sc2.fit_transform(X_norm['Fare'].values.reshape((-1, 1)))

# %%
run_linear_models(X_norm, y)
# Out:
# LogisticRegression
# RidgeClassifier
# SGDClassifier
# PassiveAggressiveClassifier
# SVC
# C:\Users\RobertAlonso\Anaconda3\envs\kaggle\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.stochastic_gradient.SGDClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# C:\Users\RobertAlonso\Anaconda3\envs\kaggle\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:128: FutureWarning: max_iter and tol parameters have been added in <class 'sklearn.linear_model.passive_aggressive.PassiveAggressiveClassifier'> in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   "and default tol will be 1e-3." % type(self), FutureWarning)
# LinearSVC
# MLPClassifier
# C:\Users\RobertAlonso\Anaconda3\envs\kaggle\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
results
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 2            AdaBoostClassifier  0.789001      0.008399  0.723547
# 3    GradientBoostingClassifier  0.824916      0.019244  0.757814
# 4                 XGBClassifier  0.821549      0.014547  0.756280
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 7            LogisticRegression  0.795735      0.019309  0.717724
# 8               RidgeClassifier  0.795735      0.011446  0.719034
# 9                 SGDClassifier  0.585859      0.016722  0.458404
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 11                          SVC  0.680135      0.020756  0.529953
# 12                    LinearSVC  0.613917      0.117583  0.526530
# 13                MLPClassifier  0.671156      0.034373  0.446757
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 19                SGDClassifier  0.622896      0.059537  0.469527
# 20                XGBClassifier  0.819304      0.013561  0.750959
# 21                XGBClassifier  0.824916      0.012598  0.757413
# 22           LogisticRegression  0.800224      0.018305  0.723695
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 24                SGDClassifier  0.656566      0.176374  0.646306
# 25  PassiveAggressiveClassifier  0.638608      0.183542  0.643248
# 26                          SVC  0.812570      0.011111  0.735369
# 27                    LinearSVC  0.797980      0.008247  0.724658
# 28                MLPClassifier  0.803591      0.012992  0.728779
#
#     f1-score-std   time
# 0       0.024212    111
# 1       0.007580     64
# 2       0.021509    256
# 3       0.025988    202
# 4       0.022376    116
# 5       0.019489     49
# 6       0.015169  26554
# 7       0.022204     44
# 8       0.017241     74
# 9       0.126533     27
# 10      0.073323     24
# 11      0.066454    130
# 12      0.107063    129
# 13      0.069996    137
# 14      0.051903     35
# 15      0.037302     37
# 16      0.040408    851
# 17      0.030389     31
# 18      0.016951     24
# 19      0.087364     40
# 20      0.020572    153
# 21      0.021329    134
# 22      0.024161     34
# 23      0.010951     32
# 24      0.059599     32
# 25      0.065077     38
# 26      0.014920     61
# 27      0.013497    149
# 28      0.015843   1886

# %%
X_all_norm = X_nan.copy()

# %%
sc = MinMaxScaler()
X_all_norm = pd.DataFrame(sc.fit_transform(X_all_norm), columns=X_norm.columns)

# %%
run_linear_models(X_all_norm, y)
# Out:
# LogisticRegression
# RidgeClassifier
# SGDClassifier
# PassiveAggressiveClassifier
# SVC
# LinearSVC
# MLPClassifier

# %%
results
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 2            AdaBoostClassifier  0.789001      0.008399  0.723547
# 3    GradientBoostingClassifier  0.824916      0.019244  0.757814
# 4                 XGBClassifier  0.821549      0.014547  0.756280
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 7            LogisticRegression  0.795735      0.019309  0.717724
# 8               RidgeClassifier  0.795735      0.011446  0.719034
# 9                 SGDClassifier  0.585859      0.016722  0.458404
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 11                          SVC  0.680135      0.020756  0.529953
# 12                    LinearSVC  0.613917      0.117583  0.526530
# 13                MLPClassifier  0.671156      0.034373  0.446757
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 19                SGDClassifier  0.622896      0.059537  0.469527
# 20                XGBClassifier  0.819304      0.013561  0.750959
# 21                XGBClassifier  0.824916      0.012598  0.757413
# 22           LogisticRegression  0.800224      0.018305  0.723695
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 24                SGDClassifier  0.656566      0.176374  0.646306
# 25  PassiveAggressiveClassifier  0.638608      0.183542  0.643248
# 26                          SVC  0.812570      0.011111  0.735369
# 27                    LinearSVC  0.797980      0.008247  0.724658
# 28                MLPClassifier  0.803591      0.012992  0.728779
# 29           LogisticRegression  0.797980      0.012598  0.724725
# 30              RidgeClassifier  0.794613      0.005498  0.722274
# 31                SGDClassifier  0.795735      0.008837  0.698333
# 32  PassiveAggressiveClassifier  0.640853      0.173443  0.600770
# 33                          SVC  0.786756      0.012992  0.710148
# 34                    LinearSVC  0.797980      0.010997  0.725477
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 36           LogisticRegression  0.797980      0.012598  0.724725
# 37              RidgeClassifier  0.794613      0.005498  0.722274
# 38                SGDClassifier  0.787879      0.014547  0.711262
# 39  PassiveAggressiveClassifier  0.632997      0.171772  0.605296
# 40                          SVC  0.786756      0.012992  0.710148
# 41                    LinearSVC  0.797980      0.010997  0.725477
# 42                MLPClassifier  0.812570      0.013837  0.732228
#
#     f1-score-std   time
# 0       0.024212    111
# 1       0.007580     64
# 2       0.021509    256
# 3       0.025988    202
# 4       0.022376    116
# 5       0.019489     49
# 6       0.015169  26554
# 7       0.022204     44
# 8       0.017241     74
# 9       0.126533     27
# 10      0.073323     24
# 11      0.066454    130
# 12      0.107063    129
# 13      0.069996    137
# 14      0.051903     35
# 15      0.037302     37
# 16      0.040408    851
# 17      0.030389     31
# 18      0.016951     24
# 19      0.087364     40
# 20      0.020572    153
# 21      0.021329    134
# 22      0.024161     34
# 23      0.010951     32
# 24      0.059599     32
# 25      0.065077     38
# 26      0.014920     61
# 27      0.013497    149
# 28      0.015843   1886
# 29      0.017808     28
# 30      0.008471     33
# 31      0.035907     36
# 32      0.093164     45
# 33      0.020564     92
# 34      0.017092     38
# 35      0.014096   1723
# 36      0.017808     33
# 37      0.008471     41
# 38      0.022115    154
# 39      0.086715    146
# 40      0.020564     44
# 41      0.017092     38
# 42      0.014426   1668

# %%
results[results['model'].apply(lambda x: x in ['CatBoostClassifier', 'XGBClassifier'])]
# Out:
#                  model  accuracy  accuracy-std  f1-score  f1-score-std   time
# 4        XGBClassifier  0.821549      0.014547  0.756280      0.022376    116
# 6   CatBoostClassifier  0.826038      0.011111  0.762610      0.015169  26554
# 20       XGBClassifier  0.819304      0.013561  0.750959      0.020572    153
# 21       XGBClassifier  0.824916      0.012598  0.757413      0.021329    134
# 47       XGBClassifier  0.824916      0.012598  0.757413      0.021329    125
# 49  CatBoostClassifier  0.820426      0.017675  0.752752      0.027106  30811

# %%
run_ensemble_models(X_all_norm, y, X_all_norm)
# Out:
# RandomForestClassifier
# ExtraTreesClassifier
# AdaBoostClassifier
# GradientBoostingClassifier
# XGBClassifier
# LGBMClassifier
# CatBoostClassifier

# %%
results
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 2            AdaBoostClassifier  0.789001      0.008399  0.723547
# 3    GradientBoostingClassifier  0.824916      0.019244  0.757814
# 4                 XGBClassifier  0.821549      0.014547  0.756280
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 7            LogisticRegression  0.795735      0.019309  0.717724
# 8               RidgeClassifier  0.795735      0.011446  0.719034
# 9                 SGDClassifier  0.585859      0.016722  0.458404
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 11                          SVC  0.680135      0.020756  0.529953
# 12                    LinearSVC  0.613917      0.117583  0.526530
# 13                MLPClassifier  0.671156      0.034373  0.446757
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 19                SGDClassifier  0.622896      0.059537  0.469527
# 20                XGBClassifier  0.819304      0.013561  0.750959
# 21                XGBClassifier  0.824916      0.012598  0.757413
# 22           LogisticRegression  0.800224      0.018305  0.723695
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 24                SGDClassifier  0.656566      0.176374  0.646306
# 25  PassiveAggressiveClassifier  0.638608      0.183542  0.643248
# 26                          SVC  0.812570      0.011111  0.735369
# 27                    LinearSVC  0.797980      0.008247  0.724658
# 28                MLPClassifier  0.803591      0.012992  0.728779
# 29           LogisticRegression  0.797980      0.012598  0.724725
# 30              RidgeClassifier  0.794613      0.005498  0.722274
# 31                SGDClassifier  0.795735      0.008837  0.698333
# 32  PassiveAggressiveClassifier  0.640853      0.173443  0.600770
# 33                          SVC  0.786756      0.012992  0.710148
# 34                    LinearSVC  0.797980      0.010997  0.725477
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 36           LogisticRegression  0.797980      0.012598  0.724725
# 37              RidgeClassifier  0.794613      0.005498  0.722274
# 38                SGDClassifier  0.787879      0.014547  0.711262
# 39  PassiveAggressiveClassifier  0.632997      0.171772  0.605296
# 40                          SVC  0.786756      0.012992  0.710148
# 41                    LinearSVC  0.797980      0.010997  0.725477
# 42                MLPClassifier  0.812570      0.013837  0.732228
# 43       RandomForestClassifier  0.799102      0.015141  0.724675
# 44         ExtraTreesClassifier  0.793490      0.006919  0.720197
# 45           AdaBoostClassifier  0.797980      0.008247  0.734231
# 46   GradientBoostingClassifier  0.824916      0.012598  0.758562
# 47                XGBClassifier  0.824916      0.012598  0.757413
# 48               LGBMClassifier  0.803591      0.020264  0.719468
# 49           CatBoostClassifier  0.820426      0.017675  0.752752
#
#     f1-score-std   time
# 0       0.024212    111
# 1       0.007580     64
# 2       0.021509    256
# 3       0.025988    202
# 4       0.022376    116
# 5       0.019489     49
# 6       0.015169  26554
# 7       0.022204     44
# 8       0.017241     74
# 9       0.126533     27
# 10      0.073323     24
# 11      0.066454    130
# 12      0.107063    129
# 13      0.069996    137
# 14      0.051903     35
# 15      0.037302     37
# 16      0.040408    851
# 17      0.030389     31
# 18      0.016951     24
# 19      0.087364     40
# 20      0.020572    153
# 21      0.021329    134
# 22      0.024161     34
# 23      0.010951     32
# 24      0.059599     32
# 25      0.065077     38
# 26      0.014920     61
# 27      0.013497    149
# 28      0.015843   1886
# 29      0.017808     28
# 30      0.008471     33
# 31      0.035907     36
# 32      0.093164     45
# 33      0.020564     92
# 34      0.017092     38
# 35      0.014096   1723
# 36      0.017808     33
# 37      0.008471     41
# 38      0.022115    154
# 39      0.086715    146
# 40      0.020564     44
# 41      0.017092     38
# 42      0.014426   1668
# 43      0.031868    106
# 44      0.012981     74
# 45      0.015643    250
# 46      0.024533    194
# 47      0.021329    125
# 48      0.023510     50
# 49      0.027106  30811

# %%
results[results['model']=='GradientBoostingClassifier']
# Out:
#                          model  accuracy  accuracy-std  f1-score  \
# 3   GradientBoostingClassifier  0.824916      0.019244  0.757814
# 46  GradientBoostingClassifier  0.824916      0.012598  0.758562
#
#     f1-score-std time
# 3       0.025988  202
# 46      0.024533  194

# %%
results.iloc[results['accuracy'].sort_values(ascending=False).index].head(10)
# Out:
#                          model  accuracy  accuracy-std  f1-score  \
# 6           CatBoostClassifier  0.826038      0.011111  0.762610
# 47               XGBClassifier  0.824916      0.012598  0.757413
# 46  GradientBoostingClassifier  0.824916      0.012598  0.758562
# 3   GradientBoostingClassifier  0.824916      0.019244  0.757814
# 21               XGBClassifier  0.824916      0.012598  0.757413
# 4                XGBClassifier  0.821549      0.014547  0.756280
# 49          CatBoostClassifier  0.820426      0.017675  0.752752
# 20               XGBClassifier  0.819304      0.013561  0.750959
# 35               MLPClassifier  0.812570      0.012397  0.733779
# 42               MLPClassifier  0.812570      0.013837  0.732228
#
#     f1-score-std   time
# 6       0.015169  26554
# 47      0.021329    125
# 46      0.024533    194
# 3       0.025988    202
# 21      0.021329    134
# 4       0.022376    116
# 49      0.027106  30811
# 20      0.020572    153
# 35      0.014096   1723
# 42      0.014426   1668

# %%
top = results.iloc[results['accuracy'].sort_values(ascending=False).index].drop_duplicates('model')

# %%
top
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 47                XGBClassifier  0.824916      0.012598  0.757413
# 46   GradientBoostingClassifier  0.824916      0.012598  0.758562
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 26                          SVC  0.812570      0.011111  0.735369
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 48               LGBMClassifier  0.803591      0.020264  0.719468
# 22           LogisticRegression  0.800224      0.018305  0.723695
# 34                    LinearSVC  0.797980      0.010997  0.725477
# 45           AdaBoostClassifier  0.797980      0.008247  0.734231
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 31                SGDClassifier  0.795735      0.008837  0.698333
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 32  PassiveAggressiveClassifier  0.640853      0.173443  0.600770
#
#     f1-score-std   time
# 6       0.015169  26554
# 47      0.021329    125
# 46      0.024533    194
# 35      0.014096   1723
# 26      0.014920     61
# 0       0.024212    111
# 1       0.007580     64
# 48      0.023510     50
# 22      0.024161     34
# 34      0.017092     38
# 45      0.015643    250
# 23      0.010951     32
# 31      0.035907     36
# 18      0.016951     24
# 14      0.051903     35
# 15      0.037302     37
# 17      0.030389     31
# 16      0.040408    851
# 32      0.093164     45

# %%
top_f1 = results.iloc[results['f1-score'].sort_values(ascending=False).index].drop_duplicates('model')

# %%
top_f1
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 46   GradientBoostingClassifier  0.824916      0.012598  0.758562
# 47                XGBClassifier  0.824916      0.012598  0.757413
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 26                          SVC  0.812570      0.011111  0.735369
# 45           AdaBoostClassifier  0.797980      0.008247  0.734231
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 34                    LinearSVC  0.797980      0.010997  0.725477
# 36           LogisticRegression  0.797980      0.012598  0.724725
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 38                SGDClassifier  0.787879      0.014547  0.711262
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 25  PassiveAggressiveClassifier  0.638608      0.183542  0.643248
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
#
#     f1-score-std   time
# 6       0.015169  26554
# 46      0.024533    194
# 47      0.021329    125
# 1       0.007580     64
# 26      0.014920     61
# 45      0.015643    250
# 35      0.014096   1723
# 0       0.024212    111
# 5       0.019489     49
# 18      0.016951     24
# 34      0.017092     38
# 36      0.017808     33
# 23      0.010951     32
# 38      0.022115    154
# 14      0.051903     35
# 15      0.037302     37
# 25      0.065077     38
# 17      0.030389     31
# 16      0.040408    851

# %%
run_model(RandomForestClassifier(n_estimators=100, max_depth=5, min_samples_leaf=2), X_all_norm, y)
# Out:
# RandomForestClassifier

# %%
results
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 0        RandomForestClassifier  0.806958      0.014108  0.731689
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 2            AdaBoostClassifier  0.789001      0.008399  0.723547
# 3    GradientBoostingClassifier  0.824916      0.019244  0.757814
# 4                 XGBClassifier  0.821549      0.014547  0.756280
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 7            LogisticRegression  0.795735      0.019309  0.717724
# 8               RidgeClassifier  0.795735      0.011446  0.719034
# 9                 SGDClassifier  0.585859      0.016722  0.458404
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 11                          SVC  0.680135      0.020756  0.529953
# 12                    LinearSVC  0.613917      0.117583  0.526530
# 13                MLPClassifier  0.671156      0.034373  0.446757
# 14                   GaussianNB  0.775533      0.030407  0.695962
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 19                SGDClassifier  0.622896      0.059537  0.469527
# 20                XGBClassifier  0.819304      0.013561  0.750959
# 21                XGBClassifier  0.824916      0.012598  0.757413
# 22           LogisticRegression  0.800224      0.018305  0.723695
# 23              RidgeClassifier  0.795735      0.006919  0.724176
# 24                SGDClassifier  0.656566      0.176374  0.646306
# 25  PassiveAggressiveClassifier  0.638608      0.183542  0.643248
# 26                          SVC  0.812570      0.011111  0.735369
# 27                    LinearSVC  0.797980      0.008247  0.724658
# 28                MLPClassifier  0.803591      0.012992  0.728779
# 29           LogisticRegression  0.797980      0.012598  0.724725
# 30              RidgeClassifier  0.794613      0.005498  0.722274
# 31                SGDClassifier  0.795735      0.008837  0.698333
# 32  PassiveAggressiveClassifier  0.640853      0.173443  0.600770
# 33                          SVC  0.786756      0.012992  0.710148
# 34                    LinearSVC  0.797980      0.010997  0.725477
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 36           LogisticRegression  0.797980      0.012598  0.724725
# 37              RidgeClassifier  0.794613      0.005498  0.722274
# 38                SGDClassifier  0.787879      0.014547  0.711262
# 39  PassiveAggressiveClassifier  0.632997      0.171772  0.605296
# 40                          SVC  0.786756      0.012992  0.710148
# 41                    LinearSVC  0.797980      0.010997  0.725477
# 42                MLPClassifier  0.812570      0.013837  0.732228
# 43       RandomForestClassifier  0.799102      0.015141  0.724675
# 44         ExtraTreesClassifier  0.793490      0.006919  0.720197
# 45           AdaBoostClassifier  0.797980      0.008247  0.734231
# 46   GradientBoostingClassifier  0.824916      0.012598  0.758562
# 47                XGBClassifier  0.824916      0.012598  0.757413
# 48               LGBMClassifier  0.803591      0.020264  0.719468
# 49           CatBoostClassifier  0.820426      0.017675  0.752752
# 50         ExtraTreesClassifier  0.801347      0.008247  0.736875
# 51         ExtraTreesClassifier  0.810325      0.005723  0.729654
# 52       RandomForestClassifier  0.820426      0.003174  0.743435
#
#     f1-score-std   time
# 0       0.024212    111
# 1       0.007580     64
# 2       0.021509    256
# 3       0.025988    202
# 4       0.022376    116
# 5       0.019489     49
# 6       0.015169  26554
# 7       0.022204     44
# 8       0.017241     74
# 9       0.126533     27
# 10      0.073323     24
# 11      0.066454    130
# 12      0.107063    129
# 13      0.069996    137
# 14      0.051903     35
# 15      0.037302     37
# 16      0.040408    851
# 17      0.030389     31
# 18      0.016951     24
# 19      0.087364     40
# 20      0.020572    153
# 21      0.021329    134
# 22      0.024161     34
# 23      0.010951     32
# 24      0.059599     32
# 25      0.065077     38
# 26      0.014920     61
# 27      0.013497    149
# 28      0.015843   1886
# 29      0.017808     28
# 30      0.008471     33
# 31      0.035907     36
# 32      0.093164     45
# 33      0.020564     92
# 34      0.017092     38
# 35      0.014096   1723
# 36      0.017808     33
# 37      0.008471     41
# 38      0.022115    154
# 39      0.086715    146
# 40      0.020564     44
# 41      0.017092     38
# 42      0.014426   1668
# 43      0.031868    106
# 44      0.012981     74
# 45      0.015643    250
# 46      0.024533    194
# 47      0.021329    125
# 48      0.023510     50
# 49      0.027106  30811
# 50      0.010053    556
# 51      0.004691    481
# 52      0.017484    541

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ## Test

# %%
X_test = test.drop(['PassengerId', 'Name', 'Cabin', 'Ticket'], axis=1)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 7 columns):
# Pclass      418 non-null int64
# Sex         418 non-null object
# Age         332 non-null float64
# SibSp       418 non-null int64
# Parch       418 non-null int64
# Fare        417 non-null float64
# Embarked    418 non-null object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 22.9+ KB

# %%
X_test_norm = X_test.copy()
X_test_norm['Age'] = X_test_norm['Age'].fillna(X_test_norm['Age'].median()).astype(float)
X_test_norm['Fare'] = X_test_norm['Fare'].fillna(X_test_norm['Fare'].median()).astype(float)
X_test_norm['Embarked'] = X_test_norm['Embarked'].fillna('N')

X_test_norm['Sex'] = lbl1.transform(X_test_norm['Sex'])
X_test_norm['Embarked'] = lbl2.transform(X_test_norm['Embarked'])

# %%
X_test_norm = pd.DataFrame(sc.transform(X_test_norm), columns=X_test_norm.columns)

# %%
X_test_norm.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  418.000000  418.000000  418.000000  418.000000  418.000000  418.000000
# mean     0.632775    0.636364    0.366666    0.055921    0.065391    0.069441
# std      0.420919    0.481622    0.159635    0.112095    0.163571    0.109012
# min      0.000000    0.000000   -0.003141    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.283740    0.000000    0.000000    0.015412
# 50%      1.000000    1.000000    0.334004    0.000000    0.000000    0.028213
# 75%      1.000000    1.000000    0.443956    0.125000    0.000000    0.061429
# max      1.000000    1.000000    0.949736    1.000000    1.500000    1.000000
#
#          Embarked
# count  418.000000
# mean     0.719298
# std      0.421757
# min      0.000000
# 25%      0.666667
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
X_all_norm.describe()
# Out:
#            Pclass         Sex         Age       SibSp       Parch        Fare  \
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.654321    0.647587    0.363679    0.065376    0.063599    0.062858
# std      0.418036    0.477990    0.163605    0.137843    0.134343    0.096995
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.500000    0.000000    0.271174    0.000000    0.000000    0.015440
# 50%      1.000000    1.000000    0.346569    0.000000    0.000000    0.028213
# 75%      1.000000    1.000000    0.434531    0.125000    0.000000    0.060508
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          Embarked
# count  891.000000
# mean     0.781145
# std      0.389133
# min      0.000000
# 25%      0.666667
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# ## Submission

# %%
model = ExtraTreesClassifier(n_estimators=100, max_depth=5, min_samples_leaf=2)
model.fit(X_all_norm, train['Survived'])
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=5, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_pred = model.predict(X_test_norm)

# %%
submit = pd.DataFrame()
submit['PassengerId'] = test['PassengerId']
submit['Survived'] = y_pred.astype(int)

# %%
submit.to_csv('ExtraTrees.csv', index=False)

# %% [markdown]
# ## More testing

# %%
results.columns
# Out:
# Index(['model', 'accuracy', 'accuracy-std', 'f1-score', 'f1-score-std',
#        'time'],
#       dtype='object')

# %%
std = results.iloc[results['accuracy-std'].sort_values().index].drop_duplicates('model')

# %%
std
# Out:
#                           model  accuracy  accuracy-std  f1-score  \
# 1          ExtraTreesClassifier  0.805836      0.001587  0.735611
# 52       RandomForestClassifier  0.820426      0.003174  0.743435
# 37              RidgeClassifier  0.794613      0.005498  0.722274
# 45           AdaBoostClassifier  0.797980      0.008247  0.734231
# 27                    LinearSVC  0.797980      0.008247  0.724658
# 31                SGDClassifier  0.795735      0.008837  0.698333
# 26                          SVC  0.812570      0.011111  0.735369
# 6            CatBoostClassifier  0.826038      0.011111  0.762610
# 35                MLPClassifier  0.812570      0.012397  0.733779
# 36           LogisticRegression  0.797980      0.012598  0.724725
# 47                XGBClassifier  0.824916      0.012598  0.757413
# 17         KNeighborsClassifier  0.693603      0.012598  0.568422
# 46   GradientBoostingClassifier  0.824916      0.012598  0.758562
# 5                LGBMClassifier  0.801347      0.012598  0.727761
# 18       DecisionTreeClassifier  0.792368      0.013837  0.727593
# 10  PassiveAggressiveClassifier  0.625140      0.020264  0.409967
# 15                  BernoulliNB  0.773288      0.020997  0.688196
# 16    GaussianProcessClassifier  0.693603      0.023967  0.567926
# 14                   GaussianNB  0.775533      0.030407  0.695962
#
#     f1-score-std   time
# 1       0.007580     64
# 52      0.017484    541
# 37      0.008471     41
# 45      0.015643    250
# 27      0.013497    149
# 31      0.035907     36
# 26      0.014920     61
# 6       0.015169  26554
# 35      0.014096   1723
# 36      0.017808     33
# 47      0.021329    125
# 17      0.030389     31
# 46      0.024533    194
# 5       0.019489     49
# 18      0.016951     24
# 10      0.073323     24
# 15      0.037302     37
# 16      0.040408    851
# 14      0.051903     35
